# %% [markdown]
# ## Using Jupyter Notebook Overview
#
# Jupyter notebook conists of cells stacked vertically.
# <br>Types of cells: Code (default), Markdown, or Raw.
# <br>You can change Cell type from the menu
# <br>(Cell > Cell Type > ...)
# <br>
# <br>This cell is of type "Markdown".
# <br>Markdown type is used to write documentation.
# <br>See a cheatsheet here:
# <br>  https://github.com/adam-p/markdown-here/wiki/Markdown-Here-Cheatsheet
# <br>
# <br>Dowble-click on this cell to see its code.
# <br>Shift-Enter to see how it is looked compiled
# <br>
# <br>You can use HTML inside Markdown, or you can use simpler Markdown syntax.
# <br>You can include links
# <br>You can control font (type, size, style).
# <br>You can make lists
# * item1
# - item2
# + item3
#
# <br>You can make tables
#
# | Tables        | Are           | Cool  |
# | ------------- |:-------------:| -----:|
# | col 3 is      | right-aligned | $1600 |
# | col 2 is      | centered      |   $12 |
# | zebra stripes | are neat      |    $1 |
#
#
# Markdown | Less | Pretty
# --- | --- | ---
# *Still* | `renders` | **nicely**
# 1 | 2 | 3
#
# You can include snipets of code in different languages:
#
# ```python
# ss = "Python syntax highlighting"
# print(ss)
# ```

# %% [markdown]
# ### You can include images
#
# <br>You can control their size and alignment (left or right).
# <br>In a simplest case you can do this: ` <img src="image.JPG" alt="Drawing" style="width:200px;"/> `
# <br>
# <br>for example:
# <br><img src="images/Vanishing_Gradient.png" alt="Drawing" style="width: 400px;" />
# <br>

# %% [markdown]
# ### You can include videos
#
# <a href="http://www.youtube.com/watch?feature=player_embedded&v=-eyhCTvrEtE
# " target="_blank"><img src="http://img.youtube.com/vi/-eyhCTvrEtE/0.jpg"
# alt="Andrew Ng interviews Geoffrey Hinton" width="240" height="180" border="10" /></a>

# %% [markdown]
# <br>You can even include mathematical formulas in LaTex format:</p.
# <br> - https://github.com/mmcky/nyu-econ-370/issues/9
#
#
# $ p(x) \sim N(\mu|\sigma^2) \\\\$
#
# $p(x) \sim \frac{1}{\sqrt{2\pi\sigma^2}} \exp{ \bigg[-\frac{1}{2}\bigg( \frac{x-\mu}{\sigma}\bigg)^2 \bigg] } $
#
# $-b \pm \sqrt{b^2 - 4ac} \over 2a$
#
# $x = a_0 + \frac{1}{a_1 + \frac{1}{a_2 + \frac{1}{a_3 + a_4}}}$
#
# $\forall x \in X, \quad \exists y \leq \epsilon$
#
#
# <br>( Note - you can change size of formulas - https://www.stat.berkeley.edu/~paciorek/computingTips/Type_sizes_changing_type_si.html )
#
# <br>$ \Huge F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$
# <br>$ \Large F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$
# <br>$ \normalsize F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$
# <br>$ \small F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$
# <br>$ \scriptsize F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$
# <br>$ \tiny F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$

# %%
# This is a "Code" cell.
# You can execute the code by pressing SHIFT-ENTER
for ii in range(5):
    print("Hello ",ii)
# Out:
# Hello  0
# Hello  1
# Hello  2
# Hello  3
# Hello  4

# %% [markdown]
# ## Making graphs
#
# #### There are many libraries to show data in graphs.
# For example:
#  - Matplotlib
#  - Seaborn
#  - Bokeh
#  - Pygal
#  - Plotly
#  - Altair - simple and interactive
#
# <br> Here is a short review of those libraries:
# <br>    https://codeburst.io/overview-of-python-data-visualization-tools-e32e1f716d10
# <br>
# <br>And here is a gallery of examples for Matplotlib.
# <br>    https://matplotlib.org/2.0.2/gallery.html
# <br>You can click on each graph to see a separate page showing the code to generate this graph.
# <br>And below I copy/pasted couple examples to demonstrate how it wokrs.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import mlab
import scipy.stats

# %%
np.random.seed(0)

mu = 200
sigma = 25
n_bins = 50
x = np.random.normal(mu, sigma, size=100)

fig, ax = plt.subplots(figsize=(8, 4))

# plot the cumulative histogram
n, bins, patches = ax.hist(x, n_bins, density=1, histtype='step',
                           cumulative=True, label='Empirical')

# Add a line showing the expected distribution.
y = scipy.stats.norm.pdf(bins, mu, sigma).cumsum()
y /= y[-1]

ax.plot(bins, y, 'k--', linewidth=1.5, label='Theoretical')

# Overlay a reversed cumulative histogram.
ax.hist(x, bins=bins, density=1, histtype='step', cumulative=-1,
        label='Reversed emp.')

# tidy up the figure
ax.grid(True)
ax.legend(loc='right')
ax.set_title('Cumulative step histograms')
ax.set_xlabel('Annual rainfall (mm)')
ax.set_ylabel('Likelihood of occurrence')

plt.show();

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)

n_bins = 10
x = np.random.randn(1000, 3)

fig, axes = plt.subplots(nrows=2, ncols=2)
ax0, ax1, ax2, ax3 = axes.flatten()

colors = ['red', 'tan', 'lime']
ax0.hist(x, n_bins, density=1, histtype='bar', color=colors, label=colors)
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')

ax1.hist(x, n_bins, density=1, histtype='bar', stacked=True)
ax1.set_title('stacked bar')

ax2.hist(x, n_bins, histtype='step', stacked=True, fill=False)
ax2.set_title('stack step (unfilled)')

# Make a multiple-histogram of data-sets with different length.
x_multi = [np.random.randn(n) for n in [10000, 5000, 2000]]
ax3.hist(x_multi, n_bins, histtype='bar')
ax3.set_title('different sample sizes')

fig.tight_layout()
plt.show() ;

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0, 2*np.pi, 50)
y = np.sin(x)
y2 = y + 0.1 * np.random.normal(size=x.shape)

fig, ax = plt.subplots()
ax.plot(x, y, 'k--')
ax.plot(x, y2, 'ro')

# set ticks and tick labels
ax.set_xlim((0, 2*np.pi))
ax.set_xticks([0, np.pi, 2*np.pi])
ax.set_xticklabels(['0', '$\pi$', '2$\pi$'])
ax.set_ylim((-1.5, 1.5))
ax.set_yticks([-1, 0, 1])

# Only draw spine between the y-ticks
ax.spines['left'].set_bounds(-1, 1)
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

plt.show();  # semicolon to remove text output !!

# %%
# Altair is a declarative statistical visualization library for Python
#  - based on Vega and Vega-Lite.
#  - uses D3 Javascript library under the hood.
#  - generates big JSON object.
# Benefit - beautiful graphics.
# But - may be painful - get stuck on Javascript errors of underlying libraries.
# Advice: if you use it and experience problems, open Chrome developer console to see the errors
# -------------------
# https://altair-viz.github.io/getting_started/installation.html
# https://altair-viz.github.io/user_guide/saving_charts.html?highlight=png
# -------------------
# conda install -c conda-forge altair vega_datasets notebook vega
import altair as alt
# alt.renderers.enable('notebook')
from vega_datasets import data

# %%
# generate the graph - and drag it with the mouse
cars = data.cars()

alt.Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
).interactive()
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
