# %% [markdown]
# ### Three-Dimensional plot examples

# %%
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm  # color maps
# !python --version
# choose colors - color maps:
# https://matplotlib.org/tutorials/colors/colormaps.html
# https://matplotlib.org/3.1.1/gallery/color/colormap_reference.html
# Out:
# Python 3.9.12

# %%
# sigmoid function - can work on arrays and on individual numbers
def sigmoid(t):
    s = 1.0 / (1.0 + np.exp(-t))
    return s

# %%
# Make a 3D graph for LogisticRegression
a1 = 0.06
a2 =-0.02
b  =-0.32

x1r = np.linspace(-200, 200, 40, dtype=float)
x2r = np.linspace(-200, 200, 40, dtype=float)
y2r = np.zeros((40,40))
for i1 in range(40):
    for i2 in range(40):
        y2r[i1,i2] = sigmoid(b + a1*x1r[i1] + a2*x2r[i2])

# plot
_X1, _X2 = np.meshgrid(x1r, x2r, indexing='ij')
_ = plt.rcParams["figure.figsize"] = (8, 8) # (width, height)
fig = plt.figure();

ax = plt.axes(projection='3d')
ax.contour3D(_X1, _X2, y2r, 50, cmap=cm.Accent)

ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('y2r');
ax.view_init(200, 100)

ax.set_title("Logistic Regression is a Linear Model")
_ = plt.show();

# %%
# from Jason Brownlee
# https://machinelearningmastery.com/how-to-use-nelder-mead-optimization-in-python/
# ackley multimodal function
from numpy import arange
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import e
from numpy import pi
from numpy import meshgrid
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# --------------------------------------------------
def objective(x, y):
    """
    # objective function
    """
    myexp1 = exp(-0.2 * sqrt(0.5 * (x**2 + y**2)))
    myexp2 = exp(0.5 * (cos(2 * pi * x) + cos(2 * pi * y)))
    val_xy = -20.0 * myexp1 - myexp2 + e + 20
    return val_xy

# --------------------------------------------------
# define range for input
r_min, r_max = -5.0, 5.0
# sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 0.1)
yaxis = arange(r_min, r_max, 0.1)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# --------------------------------------------------
# compute targets
results = objective(x, y)
# --------------------------------------------------
# create a surface plot with the jet color scheme
plt.rcParams["figure.figsize"] = (12, 8)
figure = plt.figure()

axis = plt.axes(projection='3d')
axis.contour3D(_X1, _X2, y2r, 50, cmap='jet')
axis.view_init(200, 100)
plt.show()
